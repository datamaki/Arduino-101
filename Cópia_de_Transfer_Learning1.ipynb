# %% [markdown]
# <a href="https://colab.research.google.com/github/datamaki/Arduino-101/blob/main/C%C3%B3pia_de_Transfer_Learning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# 0) GPU e versões
# =========================================================
# !nvidia-smi -L || echo "Sem GPU (ok para teste, mas treina mais lento)"
import tensorflow as tf, sys, os, numpy as np
print("TF:", tf.__version__)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# Sem GPU (ok para teste, mas treina mais lento)
# TF: 2.19.0

# %%
# Setup básico (rode ANTES de criar a EfficientNet)
import tensorflow as tf
from tensorflow.keras import layers, models
# import robusto da EfficientNet (funciona em várias versões do TF/Keras)
try:
    from tensorflow.keras.applications import EfficientNetB0
except:
    from tensorflow.keras.applications.efficientnet import EfficientNetB0

IMG_SIZE = (224, 224)   # agora existe :)
BATCH = 32

# %%
# =========================================================
# 1) Dataset via TFDS (recomendado)
#    -> Já vem limpo dos arquivos corrompidos e com labels
# =========================================================
# !pip -q install -U tensorflow-datasets
import tensorflow_datasets as tfds
(ds_train, ds_val, ds_test), info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True, as_supervised=True
)
num_classes = info.features['label'].num_classes
print(info)

IMG_SIZE = (224, 224)
BATCH = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess_img(img, label):
    img = tf.image.resize(img, IMG_SIZE)
    return img, label

# Augmentation leve (só no train)
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomZoom(0.1),
])

def add_aug(img, label):
    img = data_augmentation(img, training=True)
    return img, label

train_ds = ds_train.map(preprocess_img, num_parallel_calls=AUTOTUNE)\
                   .map(add_aug, num_parallel_calls=AUTOTUNE)\
                   .batch(BATCH).prefetch(AUTOTUNE)

val_ds   = ds_val.map(preprocess_img, num_parallel_calls=AUTOTUNE)\
                 .batch(BATCH).prefetch(AUTOTUNE)

test_ds  = ds_test.map(preprocess_img, num_parallel_calls=AUTOTUNE)\
                  .batch(BATCH).prefetch(AUTOTUNE)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cats_vs_dogs/4.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cats_vs_dogs/4.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/incomplete.6P4XDC_4.0.1/cats_vs_dogs-train.tfrecord*...:   0%…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.1. Subsequent calls will reuse this data.
# tfds.core.DatasetInfo(
#     name='cats_vs_dogs',
#     full_name='cats_vs_dogs/4.0.1',
#     description="""
#     A large set of images of cats and dogs. There are 1738 corrupted images that are dropped.
#     """,
#     homepage='https://www.microsoft.com/en-us/download/details.aspx?id=54765',
#     data_dir='/root/tensorflow_datasets/cats_vs_dogs/4.0.1',
#     file_format=tfrecord,
#     download_size=786.67 MiB,
#     dataset_size=1.04 GiB,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=uint8),
#         'image/filename': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     nondeterministic_order=False,
#     splits={
#         'train': <SplitInfo num_examples=23262, num_shards=16>,
#     },
#     citation="""@Inproceedings (Conference){asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization,
#     author = {Elson, Jeremy and Douceur, John (JD) and Howell, Jon and Saul, Jared},
#     title = {Asirra: A CAPTCHA that Exploits Interest-Aligned Manual Image Categorization},
#     booktitle = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     year = {2007},
#     month = {October},
#     publisher = {Association for Computing Machinery, Inc.},
#     url = {https://www.microsoft.com/en-us/research/publication/asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization/},
#     edition = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     }""",
# )

# %%
# =========================================================
# 2) Modelo: EfficientNetB0 + cabeça nova
#    Fase 1: extrair características (base congelada)
# =========================================================
from tensorflow.keras import layers, models
try:
    from tensorflow.keras.applications import EfficientNetB0
except:
    from tensorflow.keras.applications.efficientnet import EfficientNetB0

IMG_SIZE = (224, 224)

base = EfficientNetB0(include_top=False, weights='imagenet',
                      input_shape=IMG_SIZE + (3,))
base.trainable = False

inputs = layers.Input(shape=IMG_SIZE + (3,))
x = base(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = models.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,050,852 (15.45 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %% [markdown]
# 2) Treino (fase 1) + fine-tuning

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

ckpt = ModelCheckpoint('/content/effb0_best.h5', monitor='val_accuracy', save_best_only=True)
es   = EarlyStopping(monitor='val_accuracy', patience=4, restore_best_weights=True)
rlr  = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)

history1 = model.fit(train_ds, validation_data=val_ds, epochs=10, callbacks=[ckpt, es, rlr])

# fine-tuning: destrava só o "final" da base
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss='binary_crossentropy', metrics=['accuracy'])
history2 = model.fit(train_ds, validation_data=val_ds, epochs=5, callbacks=[ckpt, es, rlr])
# Out:
# Epoch 1/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9571 - loss: 0.1489
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1534s 3s/step - accuracy: 0.9572 - loss: 0.1488 - val_accuracy: 0.9897 - val_loss: 0.0324 - learning_rate: 0.0010
# Epoch 2/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9865 - loss: 0.0385
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1532s 3s/step - accuracy: 0.9865 - loss: 0.0385 - val_accuracy: 0.9910 - val_loss: 0.0281 - learning_rate: 0.0010
# Epoch 3/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1588s 3s/step - accuracy: 0.9885 - loss: 0.0329 - val_accuracy: 0.9910 - val_loss: 0.0255 - learning_rate: 0.0010
# Epoch 4/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9903 - loss: 0.0299
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1523s 3s/step - accuracy: 0.9903 - loss: 0.0299 - val_accuracy: 0.9914 - val_loss: 0.0244 - learning_rate: 0.0010
# Epoch 5/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9889 - loss: 0.0312
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1513s 3s/step - accuracy: 0.9889 - loss: 0.0312 - val_accuracy: 0.9918 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 6/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1502s 3s/step - accuracy: 0.9896 - loss: 0.0303 - val_accuracy: 0.9918 - val_loss: 0.0242 - learning_rate: 0.0010
# Epoch 7/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1541s 3s/step - accuracy: 0.9892 - loss: 0.0297 - val_accuracy: 0.9914 - val_loss: 0.0250 - learning_rate: 0.0010
# Epoch 8/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9910 - loss: 0.0258
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1534s 3s/step - accuracy: 0.9910 - loss: 0.0258 - val_accuracy: 0.9923 - val_loss: 0.0257 - learning_rate: 0.0010
# Epoch 9/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1537s 3s/step - accuracy: 0.9904 - loss: 0.0268 - val_accuracy: 0.9918 - val_loss: 0.0243 - learning_rate: 5.0000e-04
# Epoch 10/10
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1529s 3s/step - accuracy: 0.9912 - loss: 0.0242 - val_accuracy: 0.9923 - val_loss: 0.0243 - learning_rate: 5.0000e-04
# Epoch 1/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1797s 3s/step - accuracy: 0.9587 - loss: 0.1071 - val_accuracy: 0.9910 - val_loss: 0.0286 - learning_rate: 1.0000e-05
# Epoch 2/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1720s 3s/step - accuracy: 0.9773 - loss: 0.0583 - val_accuracy: 0.9910 - val_loss: 0.0268 - learning_rate: 1.0000e-05
# Epoch 3/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1709s 3s/step - accuracy: 0.9814 - loss: 0.0484 - val_accuracy: 0.9905 - val_loss: 0.0260 - learning_rate: 1.0000e-05
# Epoch 4/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1721s 3s/step - accuracy: 0.9832 - loss: 0.0456 - val_accuracy: 0.9901 - val_loss: 0.0260 - learning_rate: 1.0000e-05
# Epoch 5/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 1765s 3s/step - accuracy: 0.9843 - loss: 0.0413 - val_accuracy: 0.9893 - val_loss: 0.0258 - learning_rate: 1.0000e-05

# %% [markdown]
# 3) Avaliar + matriz de confusão

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

val_probs = model.predict(val_ds).ravel()
val_pred  = (val_probs > 0.5).astype(int)
y_true    = np.concatenate([y.numpy() for _, y in val_ds.unbatch().batch(2048)], axis=0)

val_acc = model.evaluate(val_ds, verbose=0)[1]
test_acc = model.evaluate(test_ds, verbose=0)[1]
print(f"Val acc: {val_acc:.4f}  |  Test acc: {test_acc:.4f}")

print("\nConfusion matrix:\n", confusion_matrix(y_true, val_pred))
print("\nReport:\n", classification_report(y_true, val_pred, target_names=['cat','dog']))
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step
# Val acc: 0.9910  |  Test acc: 0.9927
#
# Confusion matrix:
#  [[1109   11]
#  [  10 1196]]
#
# Report:
#                precision    recall  f1-score   support
#
#          cat       0.99      0.99      0.99      1120
#          dog       0.99      0.99      0.99      1206
#
#     accuracy                           0.99      2326
#    macro avg       0.99      0.99      0.99      2326
# weighted avg       0.99      0.99      0.99      2326

# %% [markdown]
# 4) Salvar .h5 e .tflite

# %%
model.save('/content/effb0_transfer.h5')

import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # quantização dinâmica
tflite = converter.convert()
open('/content/effb0_transfer.tflite','wb').write(tflite)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmpkgyqlfj_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_242')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139884292212880: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   139884292215184: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   139884274226320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274225552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274227664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274226704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274227280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274230544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274230736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274227856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274230352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274226896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274237072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274237264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274106640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274106832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274106448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273058256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273058832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273057872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273074000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304818704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304818512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304818896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304826000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304826192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292210768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292213264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292214032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292213456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292213840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292214416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292214992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884349838480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274224400: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 4548072

# %%
import os, tensorflow as tf
os.makedirs("/content/models", exist_ok=True)

# 1) Salvar no formato Keras (recomendado)
model.save("/content/models/effb0_transfer.keras")   # ✅

# 2) (opcional) Também em HDF5, se precisar de compatibilidade antiga
model.save("/content/models/effb0_transfer.h5")

# 3) Exportar TFLite com quantização dinâmica
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite = converter.convert()
open("/content/models/effb0_transfer.tflite","wb").write(tflite)

# !ls -lh /content/models
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmpq6v2_xzs'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_242')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139884292212880: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   139884292215184: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   139884274226320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274225552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274227664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274226704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274227280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274228816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274230544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274230736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274227856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274229392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274230352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274226896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274231504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274232272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274233616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274237072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274236880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274235344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274237264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274234384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274106640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274106832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274106448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274108560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274109904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274110864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274107216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274112016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274114512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274116048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274118352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274115664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274120080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274111824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274121040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274119504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273058256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273058832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273057872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273059984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273060944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273061904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273063824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273064784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273062096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273066512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273065936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273067472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273068432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273069968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273070928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273074000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273071312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273072272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884273073232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304811600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304812176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304814864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304815824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304817744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304813136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304818704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304818512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304818896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304822736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304826000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304816976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304824656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304826192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884304825232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292210768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292213264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292212304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292214032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292211728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292213456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292213840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292214416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884292214992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884349838480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139884274224400: TensorSpec(shape=(), dtype=tf.resource, name=None)
# total 60M
# -rw-r--r-- 1 root root  28M Aug 12 19:32 effb0_transfer.h5
# -rw-r--r-- 1 root root  28M Aug 12 19:32 effb0_transfer.keras
# -rw-r--r-- 1 root root 4.4M Aug 12 19:32 effb0_transfer.tflite

# %% [markdown]
# copiar pro Drive:

# %%
from google.colab import drive; drive.mount("/content/drive")
# !cp /content/models/* /content/drive/MyDrive/
# Out:
# Mounted at /content/drive

# %%
import glob, tensorflow as tf, os

print("Procurando modelos…")
cands = glob.glob("/content/**/*.keras", recursive=True) + glob.glob("/content/**/*.h5", recursive=True)
for p in cands: print(" -", p)

if any(p.endswith(".keras") for p in cands):
    path = next(p for p in cands if p.endswith(".keras"))
    m = tf.keras.models.load_model(path)
    print("Carregado:", path)
elif any(p.endswith(".h5") for p in cands):
    path = next(p for p in cands if p.endswith(".h5"))
    m = tf.keras.models.load_model(path)      # checkpoint completo em .h5
    print("Carregado:", path)
    os.makedirs("/content/models", exist_ok=True)
    m.save("/content/models/effb0_transfer.keras")   # re-salva no formato novo
    print("Re-salvo em /content/models/effb0_transfer.keras")
else:
    raise FileNotFoundError("Não encontrei .keras nem .h5 em /content")
# Out:
# Procurando modelos…
#  - /content/models/effb0_transfer.keras
#  - /content/drive/MyDrive/effb0_transfer.keras
#  - /content/effb0_transfer.h5
#  - /content/effb0_best.h5
#  - /content/models/effb0_transfer.h5
#  - /content/drive/MyDrive/effb0_transfer.h5
#  - /content/drive/MyDrive/classificacao_flor_girassol/modelo_flor_girassol.h5
#  - /content/drive/MyDrive/classificacao_flor_girassol/modelo_flor_girassol_v2.h5
# Carregado: /content/models/effb0_transfer.keras
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 32 variables whereas the saved optimizer has 62 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# carregar

# %%
import tensorflow as tf
m = tf.keras.models.load_model("effb0_transfer.keras")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3127439297.py in <cell line: 0>()
#       1 import tensorflow as tf
# ----> 2 m = tf.keras.models.load_model("effb0_transfer.keras")
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=effb0_transfer.keras. Please ensure the file is an accessible `.keras` zip file.
